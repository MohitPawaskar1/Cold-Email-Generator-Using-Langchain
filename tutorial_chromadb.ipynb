# %%
import chromadb

# %%
client = chromadb.PersistentClient()
collection = client.get_or_create_collection(name="my_collection")
print(f'Collection Created: {collection.name}')
# Out:
# Collection Created: my_collection

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Mumbai"
    ],
    ids=['id1','id2']
)
print("Data Added to the Collection")
# Out:
# Data Added to the Collection

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York',
#   'This document is about Mumbai'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
document = collection.get(ids=['id1'])
document
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['This document is about New York'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
result = collection.query(
    query_texts=["Query is about Marine Drives"],
    n_results=1
)

result
# Out:
# {'ids': [['id2']],
#  'embeddings': None,
#  'documents': [['This document is about Mumbai']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None]],
#  'distances': [[1.7336921691894531]]}
